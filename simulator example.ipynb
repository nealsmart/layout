# %%
import flowMapLayout as fml
import unit
from IPython.display import Image

# %%
#make the graph and display
G, info = fml.makeGraph(fml.inferno)
fml.drawGraph(G, info, 'jraf')
Image('jraf.png')

# %%
#simulate 10,000 games
import imp
import simulator as unit
imp.reload(unit)
ctUnits = []
tUnits = []
ctUnits, tUnits = unit.makeTeams(G, info, ctUnits, tUnits)
print(unit.getResults(10000, G, info, ctUnits, tUnits))
# Out:
# CT win rate: 49.93%
